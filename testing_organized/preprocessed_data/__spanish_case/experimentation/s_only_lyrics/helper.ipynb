# %%
import os
import pandas as pd

# %%
path_data = "../../../../data/spanish/dataset"
dataset_path = "oficialDatasetEAIM2026.csv"
path_df = os.path.join(path_data, dataset_path)

path_DATA = "../../../../../data/spanish"

csv_path = f"{path_DATA}/dataset/oficialDatasetEAIM2026.csv"

df = pd.read_csv(csv_path)

display(df.head(2))
# Out:
#                         _id         artist genre  \
# 0  689a8a83a437eda121bd38ce  Laura Pausini   pop
# 1  689a8a83a437eda121bd389f        Shakira   pop
#
#                                               lyrics  \
# 0  Ya no responde ni al teléfono\nPende de un hil...
# 1  Loca\n(Loca)\nNo te ponga' bruto\n\nQue te la ...
#
#                                             composer  lyrics_word_count  \
# 0  Compuesta por: Federico Cavalli / Angelo Valsi...                445
# 1  Compuesta por: Pitbull / El Cata / Shakira / C...                360
#
#         title_songs_new              spotify_id  popularity  explicit_content  \
# 0                Se Fue  5oQadhkuEdEhtdVn0QceyZ          71             False
# 1  Loca (part. El Cata)  42k1KeBehAd83lrGt1okiC          76             False
#
#    duration_ms release_date  \
# 0       240179   2024-11-15
# 1       183693   2010-10-19
#
#                                external_urls.spotify          letras_path  \
# ...

# %%
display(df.head(1))
# Out:
#                         _id         artist genre  \
# 0  689a8a83a437eda121bd38ce  Laura Pausini   pop
#
#                                               lyrics  \
# 0  Ya no responde ni al teléfono\nPende de un hil...
#
#                                             composer  lyrics_word_count  \
# 0  Compuesta por: Federico Cavalli / Angelo Valsi...                445
#
#   title_songs_new              spotify_id  popularity  explicit_content  \
# 0          Se Fue  5oQadhkuEdEhtdVn0QceyZ          71             False
#
#    duration_ms release_date  \
# 0       240179   2024-11-15
#
#                                external_urls.spotify          letras_path  \
# 0  https://open.spotify.com/track/5oQadhkuEdEhtdV...  Laura Pausini/30278
#
#          id_yt
# 0  g-GBiuujmL8

# %%
numerical_cols = ["lyrics_word_count", "popularity", "duration_ms"]
categoricas=["artist", "lyrics", "genre", "explicit_content", "title_songs_new"]
